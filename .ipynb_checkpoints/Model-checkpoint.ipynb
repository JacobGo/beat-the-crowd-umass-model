# %%
# load data from postgres database into pandas dataframe
from sqlalchemy import create_engine
import pandas as pd
engine = create_engine('postgresql://jacob:password@206.189.69.98:5432/umass_dining')
df     = pd.read_sql_query("select * from business where location_title='Worcester Dining Commons';", con=engine)
df     = df.rename({'timestamp':'ds', 'business_level': 'y'}, axis = 1);

# %%
# setting business level to 0 if its closed
from datetime import datetime

def check_if_closed(row):
    time = row.ds.time()
    if (time < row.closing_hours and time > row.opening_hours):
        return row.y
    else:
        return 0
    
df['y']  = df.apply(check_if_closed, axis = 1)
# df = df[df.y>0]

# %%
from fbprophet import Prophet
m = Prophet()
m.fit(df)
# Out:
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.

# %%
from fbprophet.diagnostics import cross_validation
from fbprophet.plot import plot_cross_validation_metric
df_cv = cross_validation(m, initial='14 days', period='1 hour', horizon = '36 hours')
# Out:
# INFO:fbprophet:Making 11 forecasts with cutoffs between 2019-10-17 03:00:04.592709 and 2019-10-17 13:00:04.592709

# %%
fig = plot_cross_validation_metric(df_cv, metric = 'mape')
# Out:
# INFO:fbprophet:Skipping MAPE because y close to 0
# INFO:fbprophet:Skipping MAPE because y close to 0
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-031f2a12acf7> in <module>
# ----> 1 fig = plot_cross_validation_metric(df_cv, metric = 'mape')
#
# /usr/local/lib/python3.7/site-packages/fbprophet/plot.py in plot_cross_validation_metric(df_cv, metric, rolling_window, ax, figsize)
#     489     # Some work because matplotlib does not handle timedelta
#     490     # Target ~10 ticks.
# --> 491     tick_w = max(df_none['horizon'].astype('timedelta64[ns]')) / 10.
#     492     # Find the largest time resolution that has <1 unit per bin.
#     493     dts = ['D', 'h', 'm', 's', 'ms', 'us', 'ns']
#
# TypeError: 'NoneType' object is not subscriptable

# %%
future = m.make_future_dataframe(periods=36, freq = 'H')
forecast = m.predict(future)
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail(36)
# Out:
#                              ds        yhat  yhat_lower  yhat_upper
# 2298 2019-10-19 02:00:04.592709   29.125829  -38.815906   92.790893
# 2299 2019-10-19 03:00:04.592709   24.017459  -38.755124   87.291247
# 2300 2019-10-19 04:00:04.592709   19.876847  -43.288735   80.324101
# 2301 2019-10-19 05:00:04.592709   19.455745  -41.326791   77.995182
# 2302 2019-10-19 06:00:04.592709   25.468057  -36.973880   90.941505
# 2303 2019-10-19 07:00:04.592709   37.360046  -25.373748   94.927070
# 2304 2019-10-19 08:00:04.592709   52.945039  -11.709167  116.430824
# 2305 2019-10-19 09:00:04.592709   72.321973   12.293782  130.542635
# 2306 2019-10-19 10:00:04.592709   98.371849   31.077133  157.910064
# 2307 2019-10-19 11:00:04.592709  131.870517   68.227808  194.233239
# 2308 2019-10-19 12:00:04.592709  166.010091  102.574258  224.002260
# 2309 2019-10-19 13:00:04.592709  187.357966  125.768553  247.260175
# 2310 2019-10-19 14:00:04.592709  184.780606  118.839198  248.390689
# 2311 2019-10-19 15:00:04.592709  159.507094  100.127264  217.903563
# 2312 2019-10-19 16:00:04.592709  126.790833   64.244821  189.310476
# 2313 2019-10-19 17:00:04.592709  106.090436   41.364895  164.697912
# 2314 2019-10-19 18:00:04.592709  106.930321   49.796925  169.358220
# 2315 2019-10-19 19:00:04.592709  122.069239   57.472692  187.631962
# 2316 2019-10-19 20:00:04.592709  133.757657   72.228522  197.434935
# 2317 2019-10-19 21:00:04.592709  127.747067   64.676534  187.156022
# 2318 2019-10-19 22:00:04.592709  103.367612   43.410209  165.283082
# 2319 2019-10-19 23:00:04.592709   72.019490    7.020813  134.208592
# 2320 2019-10-20 00:00:04.592709   46.802561  -15.643260  105.704941
# 2321 2019-10-20 01:00:04.592709   33.087710  -29.345797   98.629436
# 2322 2019-10-20 02:00:04.592709   27.555091  -35.929531   87.115088
# 2323 2019-10-20 03:00:04.592709   24.587917  -38.040122   86.040401
# 2324 2019-10-20 04:00:04.592709   22.567927  -37.793791   83.053134
# 2325 2019-10-20 05:00:04.592709   24.236556  -36.637364   86.573604
# 2326 2019-10-20 06:00:04.592709   32.298529  -28.515009   91.392217
# 2327 2019-10-20 07:00:04.592709   46.192102  -15.822059  105.690996
# 2328 2019-10-20 08:00:04.592709   63.723818    3.944111  128.619706
# 2329 2019-10-20 09:00:04.592709   84.987048   26.750513  144.631413
# 2330 2019-10-20 10:00:04.592709  112.858453   51.314249  174.810786
# 2331 2019-10-20 11:00:04.592709  148.110738   85.783335  208.134187
# 2332 2019-10-20 12:00:04.592709  183.934034  119.565003  243.602310
# 2333 2019-10-20 13:00:04.592709  206.894852  144.849438  271.481165

# %%
fig = m.plot(forecast)
